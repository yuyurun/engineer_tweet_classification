# %%
import settings
import tweepy
import argparse
import time

import pandas as pd

import get_tweets

import re
import os

import MeCab

from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

from sklearn.model_selection import train_test_split

from sklearn import ensemble

# %%
df = pd.read_csv('../data/ki_oku/tweet_user_kizuna_100k.csv')

# %%
df[:1000]
# Out:
#      Unnamed: 0             user  \
# 0             0    serugei_anime
# 1             1       Akuma25Ren
# 2             2    coil_ganguboy
# 3             3     dkndkndkndkn
# 4             4         nqk13044
# ..          ...              ...
# 995         995  natukivenus_fez
# 996         996      tomomonn730
# 997         997       ribennka_T
# 998         998          f238LDK
# 999         999       shivanreef
#
#                                                   text
# 0    @midnight_toyosu お疲れ様でした！！ @FA_010S 万能機…？🤔🤔 @F...
# 1    @kousuke_syma キモオタが出来上がる理由が分かったよ…コミ障でうまく喋れないんだ...
# 2    RT @ARuFa_FARu: チョコシリアルの終盤に飲む「チョコ味の牛乳」が大好きなので、...
# 3    テイルズオブジアビスに出てきたインディグネイションもエドワード・D・モリスン時代から受け継が...
# 4    @DrD19688276 ちなみに年代的にはどれ位の作品なんです？車がどことなくレトロな感じ...
# ..                                                 ...
# 995  RT @kyopaedayo: 3P相手の女さん、この顔でヤリマン自称してるのヤバすぎだろ ...
# 996  キズナアイはオリジナル以外要らなくね @req_gbf1120 オンゲは変な人がよく湧くから...
# 997  RT @Ayu__sr_oO: @rinu_dayo めっちゃすごいじゃないですかwwwww...
# 998  RT @kurenaigiku622: ｱｹﾞﾅｵｼ。#FSS_jp https://t.c...
# 999  フロイ ルロイと一星が主人公では？位置エネルギーが一番ある イナズマイレブンオリオンの刻印の...
#
# [1000 rows x 3 columns]

# %%
def text_wakati(text):
    m = MeCab.Tagger('-Owakati -d /usr/local/lib/mecab/dic/mecab-ipadic-neologd ')
    wa = m.parse(text)
    wa = wa.split(' ')
    return wa

# %%
df_kizuna = df[:1000]

# %%
df_kizuna['wakati'] = df_kizuna['text'].apply(text_wakati)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_kizuna
# Out:
#      Unnamed: 0             user  \
# 0             0    serugei_anime
# 1             1       Akuma25Ren
# 2             2    coil_ganguboy
# 3             3     dkndkndkndkn
# 4             4         nqk13044
# ..          ...              ...
# 995         995  natukivenus_fez
# 996         996      tomomonn730
# 997         997       ribennka_T
# 998         998          f238LDK
# 999         999       shivanreef
#
#                                                   text  \
# 0    @midnight_toyosu お疲れ様でした！！ @FA_010S 万能機…？🤔🤔 @F...
# 1    @kousuke_syma キモオタが出来上がる理由が分かったよ…コミ障でうまく喋れないんだ...
# 2    RT @ARuFa_FARu: チョコシリアルの終盤に飲む「チョコ味の牛乳」が大好きなので、...
# 3    テイルズオブジアビスに出てきたインディグネイションもエドワード・D・モリスン時代から受け継が...
# 4    @DrD19688276 ちなみに年代的にはどれ位の作品なんです？車がどことなくレトロな感じ...
# ..                                                 ...
# 995  RT @kyopaedayo: 3P相手の女さん、この顔でヤリマン自称してるのヤバすぎだろ ...
# 996  キズナアイはオリジナル以外要らなくね @req_gbf1120 オンゲは変な人がよく湧くから...
# 997  RT @Ayu__sr_oO: @rinu_dayo めっちゃすごいじゃないですかwwwww...
# 998  RT @kurenaigiku622: ｱｹﾞﾅｵｼ。#FSS_jp https://t.c...
# 999  フロイ ルロイと一星が主人公では？位置エネルギーが一番ある イナズマイレブンオリオンの刻印の...
#
#                                                 wakati
# 0    [@, midnight, _, toyosu, お疲れ様, でし, た, ！, ！, @,...
# 1    [@, kousuke, _, syma, キモオタ, が, 出来上がる, 理由, が, 分...
# 2    [RT, @, ARuFa, _, FARu, :, チョコ, シリアル, の, 終盤, に...
# 3    [テイルズオブジアビス, に, 出, て, き, た, インディグネイション, も, エドワ...
# 4    [@, DrD, 19688276, ちなみに, 年代, 的, に, は, どれ, 位, の...
# ..                                                 ...
# 995  [RT, @, kyopaedayo, :, 3P, 相手, の, 女, さん, 、, この...
# 996  [キズナアイ, は, オリジナル, 以外, 要ら, なく, ね, @, req, _, gb...
# 997  [RT, @, Ayu, __, sr, _, oO, :, @, rinu, _, day...
# 998  [RT, @, kurenaigiku, 622, :, ｱｹﾞﾅｵｼ, 。#, FSS, ...
# 999  [フロイ, ルロイ, と, 一星, が, 主人公, で, は, ？, 位置エネルギー, が,...
#
# [1000 rows x 4 columns]

# %%
def vec2dense(vec, num_terms):
    return list(gensim.matutils.corpus2dense([vec], num_terms=num_terms).T[0])

def bagofwords_dct(docs):
    '''
    １文書が単語のリストになった文書群のリスト
    '''
    dct = gensim.corpora.Dictionary(docs)
    unfiltered = dct.token2id.keys()
    # 出現頻度　３未満の単語消す
    # 出現率が0.9以上の単語を消す
    #dct.filter_extremes(no_below=5, no_above=0.9)
    dct.filter_extremes(no_below=400, no_above=0.6)
    filtered = dct.token2id.keys()
    filtered_out = set(unfiltered) - set(filtered)
    print(len(filtered))
    print(len(filtered_out))
    return dct

# %%
kizuna_dict = bagofwords_dct(df_kizuna['wakati'].to_list())
# Out:
# 455
# 249347

# %%
kizuna_dict.token2id
# Out:
# {'"': 0,
#  '&': 1,
#  ',': 2,
#  '-': 3,
#  '00': 4,
#  '10': 5,
#  '11': 6,
#  '12': 7,
#  '18': 8,
#  ';': 9,
#  'D': 10,
#  'E': 11,
#  'F': 12,
#  'G': 13,
#  'I': 14,
#  'L': 15,
#  'M': 16,
#  'P': 17,
#  'R': 18,
#  'S': 19,
#  'Twitter': 20,
#  'V': 21,
#  'Y': 22,
#  'YouTube': 23,
#  '_:': 24,
#  'i': 25,
#  'j': 26,
#  'l': 27,
#  'n': 28,
#  'o': 29,
#  'p': 30,
#  's': 31,
#  'u': 32,
#  'w': 33,
#  'ω': 34,
#  '→': 35,
#  '✨': 36,
#  'あ': 37,
#  'あげ': 38,
#  'あと': 39,
#  'あの': 40,
#  'ありがとう': 41,
#  'あれ': 42,
#  'いえ': 43,
#  'いく': 44,
#  'いたし': 45,
#  'いつも': 46,
#  'おめでとう': 47,
#  'おり': 48,
#  'お前': 49,
#  'お願い': 50,
#  'かい': 51,
#  'かけ': 52,
#  'かなり': 53,
#  'かわいい': 54,
#  'く': 55,
#  'くらい': 56,
#  'こ': 57,
#  'こそ': 58,
#  'こちら': 59,
#  'こんな': 60,
#  'しない': 61,
#  'しまっ': 62,
#  'しよう': 63,
#  'じゃなくて': 64,
#  'すぐ': 65,
#  'ずっと': 66,
#  'ぜ': 67,
#  'ぜひ': 68,
#  'たち': 69,
#  'っていう': 70,
#  'つけ': 71,
#  'でしょ': 72,
#  'とき': 73,
#  'とりあえず': 74,
#  'どこ': 75,
#  'ながら': 76,
#  'なん': 77,
#  'なんで': 78,
#  'にて': 79,
#  'ぬ': 80,
#  'はず': 81,
#  'べき': 82,
#  'ほしい': 83,
#  'ほど': 84,
#  'ま': 85,
#  'ましょ': 86,
#  'まじ': 87,
#  'また': 88,
#  'まとめ': 89,
#  'め': 90,
#  'めちゃくちゃ': 91,
#  'めっちゃ': 92,
#  'もん': 93,
#  'やつ': 94,
#  'やら': 95,
#  'やり': 96,
#  'やる': 97,
#  'やん': 98,
#  'よろしく': 99,
#  'よろしくお願いします': 100,
#  'ら': 101,
#  'らしい': 102,
#  'る': 103,
#  'わかる': 104,
#  'わけ': 105,
#  'んで': 106,
#  'オタク': 107,
#  'キャラ': 108,
#  'ゲーム': 109,
#  'シーン': 110,
#  'ダメ': 111,
#  'フォロー': 112,
#  'プレゼント': 113,
#  'マジで': 114,
#  '一': 115,
#  '万': 116,
#  '上': 117,
#  '下さい': 118,
#  '事': 119,
#  '二': 120,
#  '今回': 121,
#  '以上': 122,
#  '以外': 123,
#  '会社': 124,
#  '作っ': 125,
#  '俺': 126,
#  '僕': 127,
#  '入り': 128,
#  '全て': 129,
#  '全員': 130,
#  '全部': 131,
#  '公開': 132,
#  '写真': 133,
#  '出る': 134,
#  '出来': 135,
#  '出来る': 136,
#  '分': 137,
#  '分から': 138,
#  '初': 139,
#  '初めて': 140,
#  '別': 141,
#  '動画': 142,
#  '参加': 143,
#  '友達': 144,
#  '名': 145,
#  '名前': 146,
#  '問題': 147,
#  '夏': 148,
#  '多い': 149,
#  '多く': 150,
#  '大': 151,
#  '大丈夫': 152,
#  '女': 153,
#  '奴': 154,
#  '嬉しい': 155,
#  '少し': 156,
#  '度': 157,
#  '待っ': 158,
#  '怖い': 159,
#  '思い': 160,
#  '情報': 161,
#  '意味': 162,
#  '手': 163,
#  '投稿': 164,
#  '推し': 165,
#  '描き': 166,
#  '放送': 167,
#  '教え': 168,
#  '数': 169,
#  '日本': 170,
#  '明日': 171,
#  '昔': 172,
#  '昨日': 173,
#  '時間': 174,
#  '書い': 175,
#  '最後': 176,
#  '最近': 177,
#  '最高': 178,
#  '本当に': 179,
#  '楽しい': 180,
#  '楽しみ': 181,
#  '様': 182,
#  '次': 183,
#  '欲しい': 184,
#  '水': 185,
#  '水着': 186,
#  '炎上': 187,
#  '画像': 188,
#  '皆さん': 189,
#  '知っ': 190,
#  '知ら': 191,
#  '第': 192,
#  '終わっ': 193,
#  '終わり': 194,
#  '結果': 195,
#  '結構': 196,
#  '聞い': 197,
#  '色': 198,
#  '草': 199,
#  '行く': 200,
#  '言い': 201,
#  '言う': 202,
#  '言わ': 203,
#  '言葉': 204,
#  '誰か': 205,
#  '車': 206,
#  '過ぎ': 207,
#  '達': 208,
#  '金': 209,
#  '開催': 210,
#  '関係': 211,
#  '面白い': 212,
#  '頭': 213,
#  '高い': 214,
#  '️': 215,
#  '！#': 216,
#  '＆': 217,
#  '：': 218,
#  '～': 219,
#  '｢': 220,
#  '!': 221,
#  '...': 222,
#  '96': 223,
#  'A': 224,
#  'C': 225,
#  'N': 226,
#  'U': 227,
#  'X': 228,
#  'Z': 229,
#  '__': 230,
#  'a': 231,
#  'c': 232,
#  'e': 233,
#  'h': 234,
#  'k': 235,
#  'news': 236,
#  'r': 237,
#  'www': 238,
#  'y': 239,
#  'z': 240,
#  '“': 241,
#  '”': 242,
#  'あなた': 243,
#  'いう': 244,
#  'いただき': 245,
#  'かも': 246,
#  'きた': 247,
#  'くん': 248,
#  'こう': 249,
#  'こういう': 250,
#  'ここ': 251,
#  'ご': 252,
#  'しよ': 253,
#  'しれ': 254,
#  'じゃん': 255,
#  'すれ': 256,
#  'せい': 257,
#  'せる': 258,
#  'そして': 259,
#  'たかっ': 260,
#  'たく': 261,
#  'たくさん': 262,
#  'ただ': 263,
#  'ため': 264,
#  'たり': 265,
#  'ちゃう': 266,
#  'ちゃっ': 267,
#  'ちゃんと': 268,
#  'ちょっと': 269,
#  'っ': 270,
#  'っぽい': 271,
#  'ところ': 272,
#  'とても': 273,
#  'どんな': 274,
#  'など': 275,
#  'なんて': 276,
#  'ねぇ': 277,
#  'ねえ': 278,
#  'ねー': 279,
#  'ほんと': 280,
#  'まだ': 281,
#  'もっと': 282,
#  'やっぱり': 283,
#  'やめ': 284,
#  'やろ': 285,
#  'られる': 286,
#  'わから': 287,
#  'イベント': 288,
#  'クソ': 289,
#  'コスプレ': 290,
#  'コミケ': 291,
#  'ツイート': 292,
#  'レベル': 293,
#  '一番': 294,
#  '一緒': 295,
#  '三': 296,
#  '予定': 297,
#  '人生': 298,
#  '他': 299,
#  '件': 300,
#  '使っ': 301,
#  '元': 302,
#  '先': 303,
#  '入っ': 304,
#  '入れ': 305,
#  '全': 306,
#  '全然': 307,
#  '内': 308,
#  '出て': 309,
#  '可愛い': 310,
#  '台風': 311,
#  '同じ': 312,
#  '君': 313,
#  '回': 314,
#  '子': 315,
#  '子供': 316,
#  '完全': 317,
#  '家': 318,
#  '寝': 319,
#  '帰っ': 320,
#  '年': 321,
#  '心': 322,
#  '忘れ': 323,
#  '思わ': 324,
#  '悪い': 325,
#  '持っ': 326,
#  '描い': 327,
#  '早く': 328,
#  '映画': 329,
#  '普通': 330,
#  '最初': 331,
#  '朝': 332,
#  '本日': 333,
#  '死ぬ': 334,
#  '死ん': 335,
#  '流れ': 336,
#  '漫画': 337,
#  '為': 338,
#  '版': 339,
#  '理由': 340,
#  '生き': 341,
#  '男': 342,
#  '相手': 343,
#  '紹介': 344,
#  '絵': 345,
#  '考え': 346,
#  '良い': 347,
#  '良かっ': 348,
#  '行き': 349,
#  '見る': 350,
#  '覚え': 351,
#  '観': 352,
#  '言え': 353,
#  '読ん': 354,
#  '誰': 355,
#  '買っ': 356,
#  '起き': 357,
#  '超': 358,
#  '運営': 359,
#  '音': 360,
#  '頃': 361,
#  '食べ': 362,
#  '？？？': 363,
#  '16': 364,
#  '2019': 365,
#  'B': 366,
#  'J': 367,
#  'O': 368,
#  'Q': 369,
#  'T': 370,
#  'amp': 371,
#  'q': 372,
#  'x': 373,
#  'いけ': 374,
#  'いや': 375,
#  'うち': 376,
#  'くれる': 377,
#  'け': 378,
#  'これから': 379,
#  'しまう': 380,
#  'す': 381,
#  'そんな': 382,
#  'ちゃ': 383,
#  'なに': 384,
#  'ほう': 385,
#  'よかっ': 386,
#  'アニメ': 387,
#  '世界': 388,
#  '今年': 389,
#  '作品': 390,
#  '先生': 391,
#  '公式': 392,
#  '出し': 393,
#  '力': 394,
#  '化': 395,
#  '向け': 396,
#  '夜': 397,
#  '実際': 398,
#  '強い': 399,
#  '後': 400,
#  '本': 401,
#  '来る': 402,
#  '気持ち': 403,
#  '無い': 404,
#  '発表': 405,
#  '確認': 406,
#  '笑っ': 407,
#  '終了': 408,
#  '絶対': 409,
#  '色々': 410,
#  '見え': 411,
#  '逆': 412,
#  '違う': 413,
#  '配信': 414,
#  '風': 415,
#  '１': 416,
#  '３': 417,
#  'm': 418,
#  'つい': 419,
#  'なあ': 420,
#  'ファン': 421,
#  '人間': 422,
#  '仕事': 423,
#  '全く': 424,
#  '声': 425,
#  '多分': 426,
#  '大変': 427,
#  '始め': 428,
#  '感': 429,
#  '新': 430,
#  '無理': 431,
#  '系': 432,
#  '謎': 433,
#  '頑張っ': 434,
#  '@_': 435,
#  'いっ': 436,
#  'え': 437,
#  'そういう': 438,
#  'そこ': 439,
#  'だって': 440,
#  'でる': 441,
#  'とこ': 442,
#  'なー': 443,
#  '受け': 444,
#  '必要': 445,
#  '理解': 446,
#  '者': 447,
#  '顔': 448,
#  '２': 449,
#  '20': 450,
#  'もらっ': 451,
#  'すごい': 452,
#  'について': 453,
#  '登場': 454}

# %%
kizuna_dict.dfs
# Out:
# {167: 276,
#  88: 496,
#  528: 201,
#  685: 299,
#  200: 249,
#  628: 285,
#  157: 272,
#  634: 161,
#  130: 277,
#  664: 716,
#  240: 426,
#  672: 648,
#  608: 217,
#  547: 319,
#  160: 365,
#  279: 108,
#  679: 155,
#  158: 397,
#  267: 566,
#  182: 373,
#  298: 145,
#  378: 682,
#  578: 151,
#  650: 293,
#  502: 691,
#  331: 330,
#  326: 141,
#  123: 691,
#  347: 315,
#  397: 291,
#  37: 132,
#  46: 107,
#  52: 205,
#  563: 136,
#  263: 440,
#  334: 212,
#  26: 178,
#  544: 119,
#  618: 310,
#  534: 135,
#  403: 759,
#  400: 478,
#  355: 137,
#  492: 445,
#  593: 239,
#  461: 258,
#  570: 183,
#  546: 120,
#  363: 524,
#  90: 509,
#  565: 187,
#  183: 797,
#  117: 760,
#  521: 649,
#  635: 234,
#  277: 275,
#  552: 353,
#  614: 384,
#  535: 382,
#  27: 232,
#  13: 619,
#  185: 307,
#  15: 446,
#  55: 280,
#  128: 155,
#  562: 183,
#  665: 531,
#  87: 591,
#  616: 233,
#  452: 181,
#  571: 450,
#  411: 167,
#  136: 435,
#  431: 156,
#  622: 455,
#  489: 674,
#  135: 103,
#  164: 546,
#  237: 224,
#  619: 171,
#  149: 134,
#  213: 791,
#  670: 174,
#  600: 247,
#  463: 360,
#  434: 376,
#  214: 661,
#  220: 335,
#  233: 629,
#  491: 177,
#  582: 386,
#  359: 190,
#  631: 500,
#  553: 166,
#  640: 186,
#  262: 345,
#  456: 148,
#  504: 124,
#  388: 601,
#  181: 593,
#  641: 505,
#  433: 674,
#  121: 340,
#  6: 562,
#  176: 462,
#  120: 102,
#  110: 573,
#  83: 503,
#  93: 113,
#  127: 221,
#  292: 408,
#  558: 132,
#  63: 140,
#  509: 709,
#  256: 428,
#  94: 154,
#  316: 136,
#  505: 246,
#  597: 116,
#  645: 536,
#  253: 628,
#  235: 374,
#  416: 440,
#  364: 193,
#  239: 511,
#  683: 103,
#  143: 310,
#  314: 478,
#  137: 778,
#  96: 433,
#  197: 127,
#  621: 101,
#  325: 221,
#  592: 491,
#  159: 104,
#  14: 109,
#  273: 551,
#  370: 703,
#  572: 118,
#  551: 272,
#  156: 217,
#  401: 261,
#  188: 543,
#  437: 676,
#  444: 268,
#  372: 289,
#  520: 770,
#  436: 478,
#  141: 712,
#  627: 289,
#  473: 166,
#  243: 414,
#  341: 341,
#  459: 163,
#  116: 115,
#  270: 146,
#  383: 609,
#  362: 247,
#  286: 675,
#  477: 269,
#  315: 272,
#  170: 524,
#  147: 407,
#  99: 231,
#  681: 101,
#  666: 436,
#  111: 150,
#  307: 129,
#  506: 225,
#  247: 303,
#  258: 300,
#  168: 351,
#  365: 305,
#  588: 525,
#  533: 727,
#  649: 189,
#  257: 412,
#  66: 149,
#  668: 335,
#  47: 155,
#  629: 129,
#  594: 249,
#  671: 236,
#  4: 467,
#  7: 237,
#  385: 226,
#  395: 537,
#  421: 114,
#  422: 632,
#  527: 749,
#  471: 202,
#  675: 161,
#  281: 304,
#  647: 111,
#  21: 339,
#  32: 340,
#  414: 531,
#  28: 314,
#  269: 308,
#  78: 465,
#  464: 505,
#  340: 115,
#  48: 173,
#  73: 116,
#  633: 244,
#  173: 467,
#  165: 623,
#  435: 633,
#  530: 239,
#  376: 267,
#  420: 115,
#  481: 757,
#  663: 541,
#  131: 537,
#  219: 204,
#  655: 562,
#  134: 763,
#  488: 184,
#  35: 125,
#  639: 167,
#  538: 120,
#  580: 234,
#  611: 767,
#  556: 203,
#  515: 116,
#  510: 478,
#  234: 694,
#  537: 490,
#  283: 140,
#  351: 795,
#  567: 371,
#  335: 196,
#  660: 229,
#  169: 216,
#  430: 176,
#  151: 149,
#  583: 155,
#  260: 681,
#  373: 136,
#  321: 170,
#  109: 144,
#  516: 342,
#  429: 220,
#  349: 369,
#  201: 611,
#  54: 144,
#  65: 175,
#  554: 210,
#  445: 499,
#  623: 134,
#  102: 171,
#  409: 209,
#  274: 179,
#  208: 252,
#  226: 484,
#  540: 133,
#  439: 324,
#  601: 122,
#  495: 412,
#  396: 406,
#  222: 753,
#  216: 447,
#  448: 202,
#  319: 211,
#  662: 352,
#  204: 191,
#  86: 655,
#  171: 417,
#  626: 170,
#  423: 597,
#  259: 642,
#  250: 792,
#  58: 145,
#  189: 423,
#  651: 237,
#  30: 287,
#  230: 409,
#  251: 392,
#  447: 521,
#  426: 168,
#  223: 399,
#  374: 787,
#  329: 183,
#  85: 112,
#  186: 411,
#  419: 329,
#  367: 213,
#  605: 626,
#  9: 359,
#  163: 407,
#  676: 243,
#  386: 304,
#  424: 216,
#  217: 325,
#  207: 494,
#  525: 435,
#  265: 525,
#  199: 268,
#  146: 649,
#  596: 263,
#  232: 536,
#  524: 145,
#  5: 719,
#  34: 162,
#  39: 195,
#  644: 389,
#  212: 310,
#  276: 352,
#  574: 194,
#  328: 212,
#  209: 289,
#  497: 304,
#  187: 783,
#  280: 615,
#  175: 461,
#  677: 178,
#  494: 244,
#  297: 160,
#  311: 174,
#  620: 379,
#  586: 303,
#  354: 136,
#  615: 231,
#  543: 252,
#  138: 679,
#  564: 338,
#  74: 242,
#  513: 742,
#  299: 126,
#  602: 172,
#  246: 678,
#  555: 143,
#  278: 136,
#  407: 201,
#  145: 392,
#  31: 349,
#  0: 259,
#  350: 115,
#  119: 474,
#  82: 620,
#  108: 555,
#  238: 543,
#  308: 124,
#  293: 111,
#  68: 158,
#  443: 219,
#  680: 241,
#  139: 136,
#  115: 367,
#  162: 129,
#  310: 318,
#  206: 268,
#  484: 296,
#  148: 256,
#  575: 349,
#  195: 526,
#  417: 267,
#  313: 100,
#  225: 748,
#  152: 563,
#  43: 147,
#  22: 106,
#  410: 320,
#  500: 500,
#  576: 639,
#  215: 162,
#  476: 356,
#  10: 187,
#  42: 138,
#  323: 198,
#  291: 366,
#  248: 229,
#  381: 434,
#  550: 237,
#  18: 359,
#  50: 139,
#  17: 331,
#  62: 121,
#  84: 574,
#  180: 414,
#  140: 756,
#  306: 122,
#  177: 451,
#  16: 470,
#  67: 153,
#  106: 546,
#  51: 141,
#  113: 572,
#  678: 168,
#  56: 124,
#  638: 105,
#  290: 211,
#  346: 140,
#  498: 132,
#  377: 397,
#  80: 496,
#  566: 540,
#  427: 611,
#  599: 675,
#  577: 694,
#  415: 306,
#  499: 114,
#  249: 541,
#  191: 328,
#  587: 212,
#  198: 102,
#  478: 107,
#  101: 414,
#  59: 222,
#  77: 108,
#  104: 102,
#  604: 430,
#  132: 117,
#  79: 504,
#  268: 139,
#  245: 537,
#  470: 218,
#  480: 478,
#  503: 385,
#  236: 253,
#  630: 132,
#  23: 191,
#  657: 192,
#  318: 180,
#  36: 119,
#  228: 395,
#  514: 232,
#  150: 122,
#  425: 135,
#  38: 389,
#  287: 124,
#  449: 330,
#  475: 191,
#  654: 114,
#  523: 203,
#  71: 187,
#  97: 656,
#  366: 482,
#  549: 402,
#  324: 115,
#  659: 102,
#  545: 270,
#  261: 251,
#  632: 104,
#  133: 132,
#  348: 128,
#  465: 196,
#  442: 110,
#  92: 452,
#  382: 581,
#  271: 332,
#  466: 191,
#  322: 145,
#  303: 224,
#  569: 203,
#  508: 125,
#  25: 137,
#  455: 159,
#  294: 128,
#  203: 202,
#  343: 434,
#  166: 216,
#  617: 211,
#  122: 397,
#  192: 249,
#  295: 394,
#  490: 159,
#  12: 190,
#  24: 139,
#  612: 790,
#  205: 210,
#  522: 722,
#  468: 153,
#  333: 386,
#  406: 358,
#  282: 236,
#  606: 679,
#  358: 355,
#  557: 109,
#  91: 158,
#  190: 434,
#  224: 295,
#  652: 250,
#  126: 230,
#  487: 171,
#  391: 106,
#  393: 607,
#  559: 101,
#  124: 333,
#  357: 238,
#  129: 300,
#  254: 694,
#  389: 109,
#  658: 584,
#  194: 513,
#  179: 533,
#  390: 374,
#  479: 141,
#  682: 330,
#  107: 597,
#  95: 518,
#  49: 136,
#  526: 558,
#  474: 425,
#  112: 182,
#  560: 378,
#  252: 481,
#  595: 120,
#  532: 154,
#  413: 196,
#  44: 127,
#  33: 213,
#  541: 253,
#  155: 169,
#  392: 576,
#  231: 451,
#  2: 596,
#  98: 348,
#  76: 101,
#  105: 170,
#  75: 606,
#  241: 783,
#  529: 231,
#  542: 256,
#  40: 161,
#  296: 234,
#  53: 288,
#  375: 397,
#  360: 653,
#  674: 369,
#  493: 266,
#  301: 237,
#  591: 542,
#  673: 413,
#  60: 124,
#  561: 139,
#  302: 162,
#  518: 248,
#  584: 527,
#  20: 410,
#  70: 101,
#  440: 249,
#  457: 318,
#  536: 309,
#  229: 349,
#  519: 594,
#  221: 311,
#  486: 590,
#  89: 122,
#  227: 577,
#  387: 193,
#  607: 144,
#  412: 222,
#  305: 125,
#  103: 578,
#  81: 442,
#  72: 144,
#  356: 637,
#  467: 101,
#  469: 329,
#  501: 457,
#  309: 106,
#  242: 193,
#  458: 511,
#  603: 264,
#  300: 488,
#  579: 393,
#  142: 137,
#  244: 434,
#  320: 491,
#  451: 104,
#  404: 189,
#  450: 461,
#  57: 147,
#  625: 187,
#  428: 203,
#  624: 274,
#  399: 540,
#  482: 176,
#  264: 310,
#  154: 318,
#  408: 216,
#  210: 166,
#  193: 172,
#  653: 263,
#  648: 455,
#  339: 677,
#  642: 166,
#  184: 178,
#  684: 173,
#  643: 510,
#  266: 559,
#  398: 463,
#  454: 146,
#  285: 129,
#  196: 429,
#  441: 201,
#  172: 204,
#  438: 423,
#  218: 583,
#  568: 117,
#  472: 265,
#  338: 469,
#  330: 163,
#  288: 317,
#  646: 455,
#  637: 232,
#  585: 109,
#  1: 459,
#  327: 242,
#  289: 174,
#  379: 402,
#  496: 447,
#  344: 142,
#  317: 405,
#  125: 250,
#  312: 107,
#  3: 262,
#  418: 115,
#  352: 471,
#  100: 604,
#  368: 395,
#  667: 160,
#  211: 582,
#  371: 238,
#  656: 288,
#  446: 384,
#  483: 335,
#  153: 271,
#  402: 242,
#  202: 177,
#  581: 104,
#  19: 376,
#  304: 203,
#  174: 229,
#  144: 485,
#  460: 329,
#  517: 473,
#  41: 137,
#  405: 164,
#  573: 106,
#  345: 168,
#  485: 545,
#  661: 229,
#  11: 205,
#  539: 461,
#  275: 146,
#  453: 192,
#  384: 168,
#  337: 222,
#  64: 154,
#  255: 626,
#  332: 796,
#  284: 105,
#  353: 254,
#  636: 220,
#  394: 413,
#  272: 195,
#  61: 158,
#  118: 140,
#  669: 622,
#  432: 109,
#  8: 206,
#  511: 589,
#  69: 148,
#  161: 208,
#  45: 274,
#  462: 219,
#  342: 299,
#  548: 176,
#  531: 540,
#  114: 144,
#  369: 223,
#  610: 519,
#  336: 203,
#  361: 292,
#  512: 269,
#  507: 595,
#  589: 401,
#  590: 333,
#  380: 517,
#  609: 229,
#  613: 526,
#  598: 333,
#  29: 120,
#  178: 799,
#  1130: 538,
#  999: 331,
#  794: 133,
#  1083: 191,
#  890: 608,
#  761: 255,
#  774: 137,
#  873: 185,
#  687: 284,
#  728: 626,
#  909: 331,
#  784: 458,
#  1055: 112,
#  919: 170,
#  843: 593,
#  1187: 113,
#  721: 175,
#  917: 330,
#  901: 336,
#  1011: 523,
#  899: 193,
#  1096: 396,
#  1164: 174,
#  884: 235,
#  775: 420,
#  741: 471,
#  776: 468,
#  961: 299,
#  906: 199,
#  688: 472,
#  880: 526,
#  839: 778,
#  689: 248,
#  930: 121,
#  1030: 121,
#  879: 752,
#  810: 522,
#  711: 117,
#  766: 274,
#  1107: 142,
#  922: 204,
#  1175: 159,
#  1012: 137,
#  871: 470,
#  1086: 244,
#  724: 167,
#  911: 153,
#  869: 433,
#  778: 141,
#  740: 591,
#  1098: 240,
#  877: 343,
#  1135: 360,
#  817: 212,
#  1245: 177,
#  1097: 521,
#  1048: 154,
#  888: 160,
#  1206: 642,
#  1053: 254,
#  977: 673,
#  1203: 254,
#  1207: 132,
#  830: 262,
#  1204: 104,
#  1229: 255,
#  997: 133,
#  1198: 336,
#  786: 352,
#  848: 742,
#  942: 282,
#  1115: 143,
#  889: 111,
#  1094: 254,
#  1148: 235,
#  1149: 199,
#  1178: 366,
#  1142: 324,
#  822: 567,
#  804: 330,
#  992: 647,
#  1222: 193,
#  1082: 206,
#  1062: 504,
#  949: 199,
#  759: 452,
#  758: 600,
#  1177: 195,
#  1243: 427,
#  1046: 613,
#  910: 105,
#  692: 287,
#  801: 200,
#  864: 327,
#  788: 634,
#  1004: 128,
#  829: 622,
#  915: 691,
#  773: 111,
#  736: 150,
#  751: 324,
#  1237: 175,
#  712: 147,
#  996: 191,
#  785: 324,
#  799: 204,
#  882: 508,
#  1197: 136,
#  809: 223,
#  876: 441,
#  791: 392,
#  1235: 195,
#  989: 670,
#  708: 178,
#  965: 103,
#  1116: 240,
#  780: 336,
#  1185: 319,
#  1230: 200,
#  1190: 307,
#  1139: 364,
#  752: 588,
#  706: 112,
#  812: 491,
#  1214: 273,
#  716: 116,
#  753: 378,
#  764: 145,
#  927: 170,
#  802: 118,
#  1194: 183,
#  867: 339,
#  1158: 223,
#  1016: 525,
#  1244: 328,
#  1084: 548,
#  1126: 511,
#  1210: 190,
#  723: 247,
#  1146: 127,
#  738: 106,
#  787: 126,
#  1160: 105,
#  1087: 149,
#  860: 175,
#  1095: 588,
#  1227: 127,
#  695: 162,
#  1109: 446,
#  1162: 203,
#  1056: 325,
#  1121: 273,
#  733: 190,
#  715: 187,
#  713: 101,
#  1002: 166,
#  1134: 133,
#  1031: 236,
#  1167: 725,
#  742: 297,
#  1136: 256,
#  1028: 214,
#  968: 417,
#  1015: 683,
#  948: 222,
#  1219: 218,
#  1217: 409,
#  1114: 126,
#  1057: 135,
#  789: 186,
#  1017: 140,
#  967: 229,
#  1202: 135,
#  1104: 244,
#  1080: 225,
#  980: 322,
#  1018: 211,
#  1157: 570,
#  976: 386,
#  1009: 139,
#  866: 128,
#  940: 607,
#  925: 132,
#  953: 275,
#  1078: 123,
#  898: 249,
#  1010: 177,
#  819: 139,
#  1183: 448,
#  853: 175,
#  705: 171,
#  998: 473,
#  878: 265,
#  1001: 273,
#  1103: 590,
#  891: 203,
#  793: 133,
#  750: 110,
#  1125: 228,
#  929: 299,
#  918: 104,
#  1008: 166,
#  946: 103,
#  1045: 161,
#  700: 237,
#  1209: 504,
#  1143: 158,
#  840: 733,
#  731: 122,
#  1122: 468,
#  969: 182,
#  854: 210,
#  1019: 276,
#  1238: 108,
#  749: 682,
#  756: 123,
#  806: 196,
#  907: 100,
#  714: 136,
#  1151: 137,
#  894: 276,
#  881: 240,
#  1182: 129,
#  808: 554,
#  932: 295,
#  737: 167,
#  921: 165,
#  959: 100,
#  1166: 110,
#  1102: 352,
#  947: 127,
#  1106: 117,
#  1124: 184,
#  897: 390,
#  739: 389,
#  1128: 421,
#  1041: 135,
#  1113: 126,
#  1201: 353,
#  690: 228,
#  1112: 127,
#  767: 475,
#  771: 104,
#  979: 326,
#  868: 681,
#  1037: 601,
#  1063: 533,
#  746: 430,
#  870: 133,
#  905: 553,
#  984: 147,
#  957: 256,
#  970: 252,
#  1144: 158,
#  1088: 252,
#  824: 197,
#  955: 117,
#  825: 435,
#  1226: 263,
#  1007: 103,
#  1034: 154,
#  974: 341,
#  743: 595,
#  693: 180,
#  841: 127,
#  933: 230,
#  1168: 406,
#  1189: 158,
#  1092: 412,
#  1133: 606,
#  1163: 258,
#  744: 166,
#  783: 200,
#  952: 332,
#  1200: 293,
#  893: 530,
#  1035: 320,
#  805: 108,
#  1171: 133,
#  941: 480,
#  1141: 473,
#  1006: 156,
#  1108: 211,
#  842: 357,
#  937: 247,
#  1050: 214,
#  1049: 204,
#  895: 184,
#  913: 224,
#  777: 377,
#  1240: 267,
#  1176: 160,
#  1076: 177,
#  923: 138,
#  1079: 183,
#  855: 744,
#  964: 222,
#  827: 546,
#  988: 303,
#  726: 523,
#  831: 226,
#  1191: 267,
#  1051: 468,
#  798: 332,
#  981: 160,
#  707: 146,
#  770: 598,
#  865: 124,
#  1077: 244,
#  820: 447,
#  1089: 119,
#  1179: 676,
#  1225: 104,
#  896: 613,
#  ...}

# %%
df_okugawa = pd.read_csv('../data/ki_oku/tweet_user_okugawa_10k.csv')

# %%
df_okugawa = df_okugawa[:1000]

# %%
df_okugawa['wakati'] = df_okugawa['text'].apply(text_wakati)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
kioku_dict = bagofwords_dct(df_kizuna['wakati'].to_list()+df_okugawa['wakati'].to_list())
# Out:
# 1180
# 379528

# %%
kioku_dict.token2id
# Out:
# {'!!': 0,
#  '"': 1,
#  '&': 2,
#  ',': 3,
#  '00': 4,
#  '000': 5,
#  '08': 6,
#  '10': 7,
#  '11': 8,
#  '12': 9,
#  '13': 10,
#  '14': 11,
#  '15': 12,
#  '18': 13,
#  '19': 14,
#  '1回': 15,
#  '1日': 16,
#  '21': 17,
#  '22': 18,
#  '23': 19,
#  '26': 20,
#  '30': 21,
#  '3人': 22,
#  '50': 23,
#  '59': 24,
#  ':/…': 25,
#  ';': 26,
#  'D': 27,
#  'E': 28,
#  'F': 29,
#  'G': 30,
#  'I': 31,
#  'L': 32,
#  'M': 33,
#  'P': 34,
#  'R': 35,
#  'S': 36,
#  'Twitter': 37,
#  'V': 38,
#  'Y': 39,
#  'YouTube': 40,
#  '_:': 41,
#  'gt': 42,
#  'ht': 43,
#  'i': 44,
#  'j': 45,
#  'l': 46,
#  'n': 47,
#  'o': 48,
#  'p': 49,
#  's': 50,
#  'u': 51,
#  'v': 52,
#  'ω': 53,
#  '…。': 54,
#  '※': 55,
#  '↓': 56,
#  '①': 57,
#  '②': 58,
#  '☆': 59,
#  '☺': 60,
#  '✨': 61,
#  'あげ': 62,
#  'いいね': 63,
#  'いえ': 64,
#  'いき': 65,
#  'いく': 66,
#  'いたし': 67,
#  'いただい': 68,
#  'いつも': 69,
#  'いない': 70,
#  'いま': 71,
#  'うん': 72,
#  'ぇ': 73,
#  'おい': 74,
#  'おめでとう': 75,
#  'おり': 76,
#  'お前': 77,
#  'お疲れ様': 78,
#  'お盆': 79,
#  'お願い': 80,
#  'かい': 81,
#  'かけ': 82,
#  'かっこいい': 83,
#  'かなり': 84,
#  'かわいい': 85,
#  'く': 86,
#  'こ': 87,
#  'こそ': 88,
#  'こちら': 89,
#  'こっち': 90,
#  'さらに': 91,
#  'しない': 92,
#  'しよう': 93,
#  'じゃなくて': 94,
#  'すぐ': 95,
#  'すげ': 96,
#  'すべて': 97,
#  'ずっと': 98,
#  'ぜ': 99,
#  'ぜひ': 100,
#  'そろそろ': 101,
#  'そんなに': 102,
#  'たち': 103,
#  'っす': 104,
#  'っていう': 105,
#  'ってな': 106,
#  'ついに': 107,
#  'つけ': 108,
#  'てん': 109,
#  'とりあえず': 110,
#  'どうぞ': 111,
#  'どこ': 112,
#  'どちら': 113,
#  'どっち': 114,
#  'どの': 115,
#  'なきゃ': 116,
#  'なるほど': 117,
#  'なんで': 118,
#  'にて': 119,
#  'による': 120,
#  'に対して': 121,
#  'ぬ': 122,
#  'はず': 123,
#  'べき': 124,
#  'ほぼ': 125,
#  'ほんとに': 126,
#  'ま': 127,
#  'ましょ': 128,
#  'まじ': 129,
#  'まだまだ': 130,
#  'まとめ': 131,
#  'め': 132,
#  'めちゃくちゃ': 133,
#  'もし': 134,
#  'もちろん': 135,
#  'もん': 136,
#  'やばい': 137,
#  'やら': 138,
#  'やり': 139,
#  'よろしく': 140,
#  'よろしくお願いします': 141,
#  'よー': 142,
#  'ら': 143,
#  'らしい': 144,
#  'り': 145,
#  'る': 146,
#  'わかり': 147,
#  'わかる': 148,
#  'わけ': 149,
#  'んで': 150,
#  'アカウント': 151,
#  'アレ': 152,
#  'オタク': 153,
#  'ガチ': 154,
#  'ガチャ': 155,
#  'キズナアイ': 156,
#  'キャラ': 157,
#  'キャンペーン': 158,
#  'ゲーム': 159,
#  'コラボ': 160,
#  'サイン': 161,
#  'シリーズ': 162,
#  'シーン': 163,
#  'スタッフ': 164,
#  'スタート': 165,
#  'ダメ': 166,
#  'チャレンジ': 167,
#  'チャンス': 168,
#  'バカ': 169,
#  'フォロー': 170,
#  'プレゼント': 171,
#  'マジで': 172,
#  'メンバー': 173,
#  'ヶ月': 174,
#  '一人': 175,
#  '一瞬': 176,
#  '万': 177,
#  '上': 178,
#  '上げ': 179,
#  '下': 180,
#  '下さい': 181,
#  '中身': 182,
#  '乗っ': 183,
#  '二': 184,
#  '二人': 185,
#  '今回': 186,
#  '今度': 187,
#  '付け': 188,
#  '以下': 189,
#  '以外': 190,
#  '休み': 191,
#  '会社': 192,
#  '体': 193,
#  '何度': 194,
#  '作っ': 195,
#  '例': 196,
#  '個': 197,
#  '個人的': 198,
#  '側': 199,
#  '僕': 200,
#  '入り': 201,
#  '全て': 202,
#  '全員': 203,
#  '全部': 204,
#  '公開': 205,
#  '円': 206,
#  '再': 207,
#  '写真': 208,
#  '凄い': 209,
#  '出る': 210,
#  '出来': 211,
#  '出来る': 212,
#  '分': 213,
#  '分から': 214,
#  '初': 215,
#  '初めて': 216,
#  '別': 217,
#  '利用': 218,
#  '助け': 219,
#  '勝て': 220,
#  '勝利': 221,
#  '勝手': 222,
#  '勢': 223,
#  '千と千尋の神隠し': 224,
#  '参加': 225,
#  '友人': 226,
#  '友達': 227,
#  '反応': 228,
#  '可能性': 229,
#  '名': 230,
#  '名前': 231,
#  '問題': 232,
#  '外': 233,
#  '多い': 234,
#  '多く': 235,
#  '大丈夫': 236,
#  '大人': 237,
#  '大会': 238,
#  '大阪': 239,
#  '失敗': 240,
#  '女': 241,
#  '女の子': 242,
#  '奴': 243,
#  '姿': 244,
#  '嬉しい': 245,
#  '対応': 246,
#  '少し': 247,
#  '居': 248,
#  '展開': 249,
#  '店': 250,
#  '度': 251,
#  '強': 252,
#  '当たっ': 253,
#  '当たる': 254,
#  '影響': 255,
#  '待っ': 256,
#  '得': 257,
#  '必ず': 258,
#  '怖い': 259,
#  '思い出し': 260,
#  '悪く': 261,
#  '情報': 262,
#  '意味': 263,
#  '戻っ': 264,
#  '手': 265,
#  '投稿': 266,
#  '抽選': 267,
#  '拡散': 268,
#  '推し': 269,
#  '描き': 270,
#  '撮っ': 271,
#  '放送': 272,
#  '教え': 273,
#  '敵': 274,
#  '新た': 275,
#  '日本': 276,
#  '昔': 277,
#  '時点': 278,
#  '更新': 279,
#  '書い': 280,
#  '最大': 281,
#  '楽しい': 282,
#  '楽しみ': 283,
#  '次': 284,
#  '毎日': 285,
#  '氏': 286,
#  '水': 287,
#  '水着': 288,
#  '流石': 289,
#  '海': 290,
#  '消え': 291,
#  '準備': 292,
#  '炎上': 293,
#  '点': 294,
#  '無': 295,
#  '無料': 296,
#  '猫': 297,
#  '現在': 298,
#  '画像': 299,
#  '疲れ': 300,
#  '皆さん': 301,
#  '着': 302,
#  '知っ': 303,
#  '知ら': 304,
#  '神': 305,
#  '笑': 306,
#  '第': 307,
#  '約': 308,
#  '終わっ': 309,
#  '終わり': 310,
#  '結婚': 311,
#  '結果': 312,
#  '結構': 313,
#  '続ける': 314,
#  '練習': 315,
#  '考える': 316,
#  '聞き': 317,
#  '興味': 318,
#  '色': 319,
#  '草': 320,
#  '言い': 321,
#  '言葉': 322,
#  '記念': 323,
#  '記憶': 324,
#  '訳': 325,
#  '試合': 326,
#  '話題': 327,
#  '誰か': 328,
#  '質問': 329,
#  '超え': 330,
#  '足': 331,
#  '車': 332,
#  '迷惑': 333,
#  '連れ': 334,
#  '連続': 335,
#  '過ぎ': 336,
#  '達': 337,
#  '部': 338,
#  '金': 339,
#  '開催': 340,
#  '関係': 341,
#  '限り': 342,
#  '隣': 343,
#  '集め': 344,
#  '電車': 345,
#  '面白い': 346,
#  '頂き': 347,
#  '頑張り': 348,
#  '頭': 349,
#  '高': 350,
#  '高い': 351,
#  '！#': 352,
#  '＆': 353,
#  '／': 354,
#  '：': 355,
#  '＼': 356,
#  '～': 357,
#  '｢': 358,
#  '｣': 359,
#  '🎉': 360,
#  '💦': 361,
#  '😆': 362,
#  '😊': 363,
#  '😭': 364,
#  '🙏': 365,
#  '🤔': 366,
#  '!': 367,
#  "'": 368,
#  '...': 369,
#  '04': 370,
#  '09': 371,
#  '17': 372,
#  '1人': 373,
#  '40': 374,
#  '8月': 375,
#  '96': 376,
#  'A': 377,
#  'C': 378,
#  'H': 379,
#  'K': 380,
#  'N': 381,
#  'U': 382,
#  'X': 383,
#  'Z': 384,
#  '__': 385,
#  'a': 386,
#  'bot': 387,
#  'c': 388,
#  'd': 389,
#  'e': 390,
#  'h': 391,
#  'k': 392,
#  'livedoor': 393,
#  'love': 394,
#  'news': 395,
#  'official': 396,
#  'r': 397,
#  'ww': 398,
#  'www': 399,
#  'y': 400,
#  'z': 401,
#  '“': 402,
#  '”': 403,
#  '‼': 404,
#  '♪': 405,
#  '\u3000#': 406,
#  'あなた': 407,
#  'あまり': 408,
#  'あー': 409,
#  'いう': 410,
#  'いただき': 411,
#  'いっぱい': 412,
#  'いつ': 413,
#  'おかしい': 414,
#  'おじさん': 415,
#  'お知らせ': 416,
#  'お金': 417,
#  'きた': 418,
#  'ぐらい': 419,
#  'こう': 420,
#  'こういう': 421,
#  'した': 422,
#  'しよ': 423,
#  'しれ': 424,
#  'じゃん': 425,
#  'すれ': 426,
#  'せい': 427,
#  'せる': 428,
#  'そのまま': 429,
#  'その後': 430,
#  'そもそも': 431,
#  'たかっ': 432,
#  'たくさん': 433,
#  'ただ': 434,
#  'たま': 435,
#  'ちなみに': 436,
#  'ちゃう': 437,
#  'ちゃっ': 438,
#  'ちゃんと': 439,
#  'っぽい': 440,
#  'てか': 441,
#  'とても': 442,
#  'とる': 443,
#  'どんな': 444,
#  'など': 445,
#  'なんと': 446,
#  'によって': 447,
#  'ねぇ': 448,
#  'ねえ': 449,
#  'ねー': 450,
#  'ばかり': 451,
#  'べ': 452,
#  'ほんと': 453,
#  'まあ': 454,
#  'まず': 455,
#  'もっと': 456,
#  'やっと': 457,
#  'やっぱり': 458,
#  'やめ': 459,
#  'やろ': 460,
#  'ゆっくり': 461,
#  'られる': 462,
#  'わかっ': 463,
#  'わから': 464,
#  'アプリ': 465,
#  'イベント': 466,
#  'イラスト': 467,
#  'カッコ': 468,
#  'カード': 469,
#  'クソ': 470,
#  'コスプレ': 471,
#  'コミケ': 472,
#  'ストーリー': 473,
#  'スマホ': 474,
#  'タイミング': 475,
#  'ニュース': 476,
#  'ネタ': 477,
#  'ホント': 478,
#  'マジ': 479,
#  'ヤバい': 480,
#  'リアル': 481,
#  'リツイート': 482,
#  'レベル': 483,
#  'ワイ': 484,
#  '一番': 485,
#  '一緒': 486,
#  '一緒に': 487,
#  '三': 488,
#  '久しぶり': 489,
#  '予定': 490,
#  '事件': 491,
#  '事実': 492,
#  '事故': 493,
#  '人たち': 494,
#  '人生': 495,
#  '今後': 496,
#  '他': 497,
#  '仲間': 498,
#  '件': 499,
#  '会場': 500,
#  '会話': 501,
#  '似': 502,
#  '余裕': 503,
#  '作る': 504,
#  '使っ': 505,
#  '使わ': 506,
#  '信じ': 507,
#  '個人': 508,
#  '元': 509,
#  '先': 510,
#  '先輩': 511,
#  '入る': 512,
#  '入れ': 513,
#  '全': 514,
#  '全然': 515,
#  '内': 516,
#  '出て': 517,
#  '分かっ': 518,
#  '切れ': 519,
#  '勘違い': 520,
#  '可愛い': 521,
#  '台風': 522,
#  '君': 523,
#  '四': 524,
#  '回': 525,
#  '報告': 526,
#  '場所': 527,
#  '増え': 528,
#  '変え': 529,
#  '変更': 530,
#  '大事': 531,
#  '女子': 532,
#  '女性': 533,
#  '娘': 534,
#  '嫌い': 535,
#  '子': 536,
#  '子供': 537,
#  '存在': 538,
#  '完全': 539,
#  '家': 540,
#  '寝': 541,
#  '左': 542,
#  '帰っ': 543,
#  '帰り': 544,
#  '帰る': 545,
#  '年': 546,
#  '幸せ': 547,
#  '当時': 548,
#  '心': 549,
#  '忘れ': 550,
#  '思わ': 551,
#  '悪い': 552,
#  '悲しい': 553,
#  '悲報': 554,
#  '感じる': 555,
#  '拡散希望': 556,
#  '挑戦': 557,
#  '描い': 558,
#  '撮影': 559,
#  '方々': 560,
#  '日本人': 561,
#  '早く': 562,
#  '映画': 563,
#  '普段': 564,
#  '普通': 565,
#  '曲': 566,
#  '最初': 567,
#  '服': 568,
#  '朝': 569,
#  '木': 570,
#  '本人': 571,
#  '本日': 572,
#  '本気': 573,
#  '楽し': 574,
#  '死ぬ': 575,
#  '死ん': 576,
#  '決まっ': 577,
#  '沢山': 578,
#  '泣い': 579,
#  '活動': 580,
#  '流れ': 581,
#  '漫画': 582,
#  '為': 583,
#  '版': 584,
#  '状況': 585,
#  '理由': 586,
#  '生き': 587,
#  '男': 588,
#  '男性': 589,
#  '発売': 590,
#  '発生': 591,
#  '相手': 592,
#  '瞬間': 593,
#  '笑う': 594,
#  '笑顔': 595,
#  '等': 596,
#  '紹介': 597,
#  '結局': 598,
#  '絵': 599,
#  '続く': 600,
#  '聞か': 601,
#  '良かっ': 602,
#  '行き': 603,
#  '行こ': 604,
#  '表現': 605,
#  '見せ': 606,
#  '覚え': 607,
#  '観': 608,
#  '言え': 609,
#  '記事': 610,
#  '誕生日': 611,
#  '説': 612,
#  '説明': 613,
#  '読ん': 614,
#  '調べ': 615,
#  '警察': 616,
#  '負け': 617,
#  '買い': 618,
#  '買う': 619,
#  '買っ': 620,
#  '起き': 621,
#  '超': 622,
#  '辛い': 623,
#  '通り': 624,
#  '逮捕': 625,
#  '遊び': 626,
#  '運営': 627,
#  '過去': 628,
#  '長い': 629,
#  '間違い': 630,
#  '難しい': 631,
#  '音': 632,
#  '頃': 633,
#  '︎': 634,
#  '＃': 635,
#  '？？？': 636,
#  'ｗ': 637,
#  '/…': 638,
#  '02': 639,
#  '16': 640,
#  '2019': 641,
#  '://…': 642,
#  'B': 643,
#  'FGO': 644,
#  'J': 645,
#  'O': 646,
#  'Q': 647,
#  'T': 648,
#  'amp': 649,
#  'b': 650,
#  'f': 651,
#  'q': 652,
#  'to': 653,
#  'x': 654,
#  '×': 655,
#  'いけ': 656,
#  'いや': 657,
#  'うち': 658,
#  'かかっ': 659,
#  'け': 660,
#  'こいつ': 661,
#  'これから': 662,
#  'こんなに': 663,
#  'ご覧': 664,
#  'さすが': 665,
#  'しまう': 666,
#  'じゃあ': 667,
#  'す': 668,
#  'それでも': 669,
#  'だし': 670,
#  'ちゃ': 671,
#  'っけ': 672,
#  'つ': 673,
#  'とも': 674,
#  'なお': 675,
#  'なかなか': 676,
#  'なぜ': 677,
#  'なに': 678,
#  'なれ': 679,
#  'のみ': 680,
#  'はい': 681,
#  'ほう': 682,
#  'みなさん': 683,
#  'みる': 684,
#  'やはり': 685,
#  'よかっ': 686,
#  'アップ': 687,
#  'アニメ': 688,
#  'セット': 689,
#  'ーー': 690,
#  '一部': 691,
#  '上がっ': 692,
#  '世界': 693,
#  '予想': 694,
#  '今年': 695,
#  '令和': 696,
#  '会': 697,
#  '作り': 698,
#  '作品': 699,
#  '使う': 700,
#  '使え': 701,
#  '元気': 702,
#  '先生': 703,
#  '入れる': 704,
#  '全力': 705,
#  '公式': 706,
#  '出し': 707,
#  '出す': 708,
#  '分かる': 709,
#  '力': 710,
#  '化': 711,
#  '取っ': 712,
#  '右': 713,
#  '合わせ': 714,
#  '向け': 715,
#  '周り': 716,
#  '味': 717,
#  '国': 718,
#  '場': 719,
#  '変わら': 720,
#  '多': 721,
#  '夜': 722,
#  '夢': 723,
#  '大好き': 724,
#  '嫌': 725,
#  '完成': 726,
#  '実は': 727,
#  '実際': 728,
#  '対策': 729,
#  '強い': 730,
#  '形': 731,
#  '思え': 732,
#  '感謝': 733,
#  '所': 734,
#  '探し': 735,
#  '方法': 736,
#  '映像': 737,
#  '時代': 738,
#  '暑さ': 739,
#  '最悪': 740,
#  '本': 741,
#  '来る': 742,
#  '来年': 743,
#  '東京': 744,
#  '気持ち': 745,
#  '無い': 746,
#  '無事': 747,
#  '物': 748,
#  '特に': 749,
#  '生まれ': 750,
#  '用': 751,
#  '痛い': 752,
#  '発表': 753,
#  '発言': 754,
#  '皆': 755,
#  '確認': 756,
#  '社長': 757,
#  '突然': 758,
#  '笑っ': 759,
#  '簡単': 760,
#  '素敵': 761,
#  '終了': 762,
#  '組': 763,
#  '経験': 764,
#  '続き': 765,
#  '綺麗': 766,
#  '胸': 767,
#  '色々': 768,
#  '見え': 769,
#  '見える': 770,
#  '見つけ': 771,
#  '解説': 772,
#  '設定': 773,
#  '評価': 774,
#  '詳細': 775,
#  '販売': 776,
#  '購入': 777,
#  '近い': 778,
#  '近く': 779,
#  '追加': 780,
#  '逆': 781,
#  '違う': 782,
#  '部分': 783,
#  '部屋': 784,
#  '配信': 785,
#  '開始': 786,
#  '際': 787,
#  '面白': 788,
#  '風': 789,
#  '３': 790,
#  '４': 791,
#  '６': 792,
#  '９': 793,
#  '1番': 794,
#  '31': 795,
#  'in': 796,
#  'm': 797,
#  'ああ': 798,
#  'あたり': 799,
#  'あんまり': 800,
#  'おき': 801,
#  'しかも': 802,
#  'しまい': 803,
#  'つい': 804,
#  'つつ': 805,
#  'とかいう': 806,
#  'ど': 807,
#  'どれ': 808,
#  'なあ': 809,
#  'なし': 810,
#  'なのか': 811,
#  'な！': 812,
#  'ぶり': 813,
#  'まくっ': 814,
#  'まさかの': 815,
#  'わからん': 816,
#  'タイプ': 817,
#  'チーム': 818,
#  'ファン': 819,
#  '人間': 820,
#  '仕事': 821,
#  '全く': 822,
#  '分かり': 823,
#  '去年': 824,
#  '取れ': 825,
#  '声': 826,
#  '夏休み': 827,
#  '多分': 828,
#  '大きな': 829,
#  '大変': 830,
#  '失礼': 831,
#  '始め': 832,
#  '愛': 833,
#  '感': 834,
#  '感想': 835,
#  '成功': 836,
#  '担当': 837,
#  '新': 838,
#  '早い': 839,
#  '時期': 840,
#  '期待': 841,
#  '楽しかっ': 842,
#  '活躍': 843,
#  '涙': 844,
#  '無理': 845,
#  '生活': 846,
#  '系': 847,
#  '続け': 848,
#  '美味しい': 849,
#  '行か': 850,
#  '謎': 851,
#  '身': 852,
#  '道': 853,
#  '間': 854,
#  '雨': 855,
#  '頑張っ': 856,
#  '食べる': 857,
#  '！(': 858,
#  '👍': 859,
#  '01': 860,
#  '03': 861,
#  '25': 862,
#  '28': 863,
#  '2b': 864,
#  '@_': 865,
#  'vs': 866,
#  '←': 867,
#  '。#': 868,
#  'いっ': 869,
#  'えっ': 870,
#  'おかげ': 871,
#  'しかし': 872,
#  'しろ': 873,
#  'そ': 874,
#  'そういう': 875,
#  'そこ': 876,
#  'だって': 877,
#  'ち': 878,
#  'つもり': 879,
#  'では': 880,
#  'でる': 881,
#  'とこ': 882,
#  'なー': 883,
#  'ねん': 884,
#  'びっくり': 885,
#  'まぁ': 886,
#  'まま': 887,
#  'やすい': 888,
#  'ツイッター': 889,
#  'ネット': 890,
#  'フォロワー': 891,
#  'ーーー': 892,
#  '久々': 893,
#  '予約': 894,
#  '人気': 895,
#  '出演': 896,
#  '制作': 897,
#  '受け': 898,
#  '号': 899,
#  '土': 900,
#  '型': 901,
#  '学校': 902,
#  '家族': 903,
#  '差': 904,
#  '復活': 905,
#  '心配': 906,
#  '必要': 907,
#  '応援': 908,
#  '想像': 909,
#  '投げ': 910,
#  '改めて': 911,
#  '攻撃': 912,
#  '楽しん': 913,
#  '残念': 914,
#  '決定': 915,
#  '注意': 916,
#  '状態': 917,
#  '現実': 918,
#  '理解': 919,
#  '監督': 920,
#  '確か': 921,
#  '置い': 922,
#  '者': 923,
#  '致し': 924,
#  '良く': 925,
#  '行動': 926,
#  '裏': 927,
#  '送っ': 928,
#  '速報': 929,
#  '違い': 930,
#  '頑張れ': 931,
#  '顔': 932,
#  '飲み': 933,
#  '２': 934,
#  '８': 935,
#  '＝': 936,
#  '＞': 937,
#  '💕': 938,
#  '05': 939,
#  '100': 940,
#  '20': 941,
#  '2019年': 942,
#  '2人': 943,
#  '[': 944,
#  'g': 945,
#  'the': 946,
#  '❤': 947,
#  'かっ': 948,
#  'すき': 949,
#  'すごく': 950,
#  'もらい': 951,
#  'わたし': 952,
#  'イメージ': 953,
#  'コメント': 954,
#  'タピオカ': 955,
#  'ボール': 956,
#  '一つ': 957,
#  '勝っ': 958,
#  '可愛': 959,
#  '始まっ': 960,
#  '彼女': 961,
#  '暑い': 962,
#  '月': 963,
#  '歌': 964,
#  '死': 965,
#  '毎回': 966,
#  '気づい': 967,
#  '火': 968,
#  '熱中症': 969,
#  '皆様': 970,
#  '素晴らしい': 971,
#  '見れ': 972,
#  '限定': 973,
#  '頂い': 974,
#  '飲ん': 975,
#  '😂': 976,
#  '24': 977,
#  '55': 978,
#  'NHK': 979,
#  'W': 980,
#  'jp': 981,
#  'させ': 982,
#  'だから': 983,
#  'もらっ': 984,
#  'テレビ': 985,
#  'リプ': 986,
#  '不安': 987,
#  '以降': 988,
#  '使い': 989,
#  '勉強': 990,
#  '口': 991,
#  '変': 992,
#  '屋': 993,
#  '延長': 994,
#  '感動': 995,
#  '新しい': 996,
#  '明らか': 997,
#  '星': 998,
#  '是非': 999,
#  ...}

# %%
kioku_dict = bagofwords_dct(df_kizuna['wakati'].to_list()+df_okugawa['wakati'].to_list())
# Out:
# 1091
# 379617

# %%
def text2bow(text,dct):
    docs_bow = dct.doc2bow(text)
    return vec2dense(dct.doc2bow(text),1091)

# %%
df_kizuna['bow'] = df_kizuna['wakati'].apply(text2bow,dct=kioku_dict)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_okugawa['bow'] = df_okugawa['wakati'].apply(text2bow,dct=kioku_dict)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_kizuna['label'] = 'kizuna'
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_okugawa['label'] = 'okuga'
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_kioku = pd.concat([df_kizuna,df_okugawa])

# %%
def make_data(df):
    all_data = df['bow'].to_list()
    all_target = df['label'].to_list()
    

    train_data, test_data, train_target, test_target = train_test_split(all_data,all_target ,test_size=0.2,random_state=256)
    #train_data, test_data, train_target, test_target, train_index , test_index = train_test_split(all_data,all_target ,all_index,test_size=0.2,random_state=256)
    /
    return train_data, test_data, train_target, test_target

# %%
train_data, test_data, train_target, test_target = make_data(df_kioku)

# %%
train_data
